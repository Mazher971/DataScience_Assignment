# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we summarize some of the popular languages, libraries, and tools used in Data Science. We will also show a few examples of arithmetic operations and conversions.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Category             |
# |-----------------|----------------------|
# | Jupyter Notebook | IDE / Notebook      |
# | RStudio          | IDE                 |
# | Apache Spark     | Big Data Framework  |
# | TensorFlow       | Machine Learning    |
# | Apache Hadoop    | Big Data Platform   |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# Below are examples of simple arithmetic expressions like addition and multiplication.

# %%
# Multiply and add numbers
(3*4) + 5

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# - List popular Data Science languages
# - Identify common Data Science libraries
# - Introduce Data Science tools
# - Perform simple arithmetic operations
# - Convert units using Python

# %% [markdown]
# ## Author
# **Your Name Here**
